# %%
# Call python libraries 
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# Read the contents of a local copy of the Checkbook
csv_file='cpi-u.csv'
data = pd.read_csv(csv_file)

# %%
data.head(10)
# Out:
#    Year   Jan   Feb   Mar   Apr   May  June  July   Aug   Sep   Oct   Nov  \
# 0  1913   9.8   9.8   9.8   9.8   9.7   9.8   9.9   9.9  10.0  10.0  10.1
# 1  1914  10.0   9.9   9.9   9.8   9.9   9.9  10.0  10.2  10.2  10.1  10.2
# 2  1915  10.1  10.0   9.9  10.0  10.1  10.1  10.1  10.1  10.1  10.2  10.3
# 3  1916  10.4  10.4  10.5  10.6  10.7  10.8  10.8  10.9  11.1  11.3  11.5
# 4  1917  11.7  12.0  12.0  12.6  12.8  13.0  12.8  13.0  13.3  13.5  13.5
# 5  1918  14.0  14.1  14.0  14.2  14.5  14.7  15.1  15.4  15.7  16.0  16.3
# 6  1919  16.5  16.2  16.4  16.7  16.9  16.9  17.4  17.7  17.8  18.1  18.5
# 7  1920  19.3  19.5  19.7  20.3  20.6  20.9  20.8  20.3  20.0  19.9  19.8
# 8  1921  19.0  18.4  18.3  18.1  17.7  17.6  17.7  17.7  17.5  17.5  17.4
# 9  1922  16.9  16.9  16.7  16.7  16.7  16.7  16.8  16.6  16.6  16.7  16.8
#
#     Dec  Annual Avg
# 0  10.0         9.9
# 1  10.1        10.0
# 2  10.3        10.1
# 3  11.6        10.9
# 4  13.7        12.8
# 5  16.5        15.1
# ...

# %%
data.tail(10)
# Out:
#      Year      Jan      Feb      Mar      Apr      May     June     July  \
# 97   2010  216.687  216.741  217.631  218.009  218.178  217.965  218.011
# 98   2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# 99   2012  226.655  227.663  229.392  230.085  229.815  229.478  229.104
# 100  2013  230.280  232.166  232.773  232.531  232.945  233.504  233.596
# 101  2014  233.916  234.781  236.293  237.072  237.900  238.343  238.250
# 102  2015  233.707  234.722  236.119  236.599  237.805  238.638  238.654
# 103  2016  236.916  237.111  238.132  239.261  240.236  241.038  240.647
# 104  2017  242.839  243.603  243.801  244.524  244.733  244.955  244.786
# 105  2018  247.867  248.991  249.554  250.546  251.588  251.989  252.006
# 106  2019  251.712  252.776  254.202      NaN      NaN      NaN      NaN
#
#          Aug      Sep      Oct      Nov      Dec  Annual Avg
# 97   218.312  218.439  218.711  218.803  219.179     218.056
# ...

# %% [markdown]
# # Diminshing value of \\$

# %% [markdown]
# # Title
#
# Description.

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("states.csv")

# %%
data
# Out:
#               Name  ID Abbreviation   Statehood          Capital  \
# 0         Delaware   1           DE   12/7/1787           Dover
# 1     Pennsylvania   2           PA  12/12/1787       Harrisburg
# 2       New Jersey   3           NJ  12/18/1787          Trenton
# 3          Georgia   4           GA    1/2/1788         Atlanta
# 4      Connecticut   5           CT    1/9/1788        Hartford
# 5    Massachusetts   6           MA    2/6/1788          Boston
# 6         Maryland   7           MD   4/28/1788       Annapolis
# 7   South Carolina   8           SC   5/23/1788         Columbia
# 8    New Hampshire   9           NH   6/21/1788          Concord
# 9         Virginia  10           VA   6/25/1788         Richmond
# 10        New York  11           NY   7/26/1788           Albany
# 11  North Carolina  12           NC  11/21/1789          Raleigh
# 12    Rhode Island  13           RI   5/29/1790       Providence
# ...
